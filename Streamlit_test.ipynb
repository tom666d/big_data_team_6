# %%
import sys
from pathlib import Path
import importlib

repo_root = Path(".").resolve()
sys.path.append(str(repo_root / "src"))

import detection.detector_dashboard as dd
importlib.reload(dd)

result = dd.run_detector("table", "workspace.team6.demo_lendingclub")
print(result["quality_score"])

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

load_dotenv(Path(".").resolve() / ".env", override=True)
print(os.getenv("OPENAI_API_KEY") is not None)

# %%
from pathlib import Path
import os

print("cwd:", Path(".").resolve())
print("cwd .env exists:", (Path(".").resolve() / ".env").exists())

# %%
import importlib
import llm.suggester_dashboard as sd
importlib.reload(sd)

results = sd.run_suggester()
print("Records generated:", len(results))

# %%
from pathlib import Path
source = Path("streamlit_app/app.py").read_text(encoding="utf-8")
compile(source, "streamlit_app/app.py", "exec")
print("app.py syntax ok")

# %%
import sys
from pathlib import Path
import importlib

repo_root = Path(".").resolve()
sys.path.append(str(repo_root / "src"))

import detection.detector_dashboard as dd
import llm.suggester_dashboard as sd

importlib.reload(dd)
importlib.reload(sd)

print("imports ok")

# %%
from pathlib import Path

print(Path("streamlit_app/app.py").exists())
print(Path("src/detection/detector_dashboard.py").exists())
print(Path("src/llm/suggester_dashboard.py").exists())
print(Path(".env").exists())

# %%
git status
